# %%
import pandas as pd

url = "https://raw.githubusercontent.com/nkmwicz/data-for-students/refs/heads/main/french-ambs.csv"

df = pd.read_csv(url)
df.head(10)
# Out:
#    id                      name    place  year    lat   long      lat_long
# 0   0        Richer, Christophe  Denmark  1543  55.68  12.57  55.68, 12.57
# 1   1        Richer, Christophe  Denmark  1541  55.68  12.57  55.68, 12.57
# 2   2        Danzay, Charles de  Denmark  1561  55.68  12.57  55.68, 12.57
# 3   3        Danzay, Charles de  Denmark  1563  55.68  12.57  55.68, 12.57
# 4   4        Danzay, Charles de  Denmark  1582  55.68  12.57  55.68, 12.57
# 5   5        Bapaume, Robert de  England  1516  51.51  -0.12  51.51, -0.12
# 6   6  Passano, Jean-Joachim de  England  1527  51.51  -0.12  51.51, -0.12
# 7   7               De Monpreat  England  1532  51.51  -0.12  51.51, -0.12
# 8   8           Du Bellay, Jean  England  1530  51.51  -0.12  51.51, -0.12
# 9   9     Castelnau, Antoine de  England  1534  51.51  -0.12  51.51, -0.12

# %%
# File paths
# abosolute paths
# starts at the root of the computer
    # /users/<user-name>/otherfile/otherfile
    # c:file...
    # f:
# relative path
    #starts at the folder we are currently in
    # use . notation to determin location
    # go back one = ../
    # got back two folders = ../../foldername/file.csv
    # current folder = ./

# %%
# write our df to the data folder.
# df.to_csv("./data/french-ambs.csv", index=False)

# %%
#read csv to df
df = pd.read_csv("./data/french-ambs.csv")
df.head()
# Out:
#    id                name    place  year    lat   long      lat_long
# 0   0  Richer, Christophe  Denmark  1543  55.68  12.57  55.68, 12.57
# 1   1  Richer, Christophe  Denmark  1541  55.68  12.57  55.68, 12.57
# 2   2  Danzay, Charles de  Denmark  1561  55.68  12.57  55.68, 12.57
# 3   3  Danzay, Charles de  Denmark  1563  55.68  12.57  55.68, 12.57
# 4   4  Danzay, Charles de  Denmark  1582  55.68  12.57  55.68, 12.57

# %%
# iloc[] uses index number and column number

df.iloc[10]
# Out:
# id                      10
# name        De Selve, Odet
# place              England
# year                  1547
# lat                  51.51
# long                 -0.12
# lat_long      51.51, -0.12
# Name: 10, dtype: object

# %%
df.iloc[100:110]
# Out:
#       id                                  name          place  year    lat  \
# 100  100                Bellièvre, Pomponne de  Swiss Cantons  1570  46.94
# 101  101  Bellièvre, Jean de, sr. de Hautefort  Swiss Cantons  1579  46.94
# 102  102                          Vigier, Jean  Swiss Cantons  1581  46.94
# 103  103                         De Pins, Jean         Venice  1517  45.44
# 104  104                         De Pins, Jean         Venice  1518  45.44
# 105  105                   Du Gabre, Dominique         Venice  1554  45.44
# 106  106                      Carmain, Paul de         Venice  1569  45.44
# 107  107                    Du Ferrier, Arnaud         Venice  1576  45.44
# 108  108                        De Selve, Odet         Venice  1551  45.44
# 109  109                        Hurault, André         Venice  1583  45.44
#
#       long      lat_long
# 100   7.45   46.94, 7.45
# 101   7.45   46.94, 7.45
# 102   7.45   46.94, 7.45
# 103  12.33  45.44, 12.33
# ...

# %%
df.iloc[0,2]
# Out:
# 'Denmark'

# %%
# .at[] .iat[] get only cells
df.at[0, "place"]
# Out:
# 'Denmark'

# %%
df.iat[0,2]
# Out:
# 'Denmark'

# %%
# rename with an iteration:
# iterrows and intertuples
# iterrows
for idx, item in df.iterrows():
    print(item["place"])
# Out:
# Denmark
# Denmark
# Denmark
# Denmark
# Denmark
# England
# England
# England
# England
# England
# England
# England
# England
# England
# England
# Geneva
# Grisons
# Grisons
# Grisons
# Grisons
# Grisons
# Grisons
# Grisons
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Netherlands
# Ottoman Empire
# Ottoman Empire
# Ottoman Empire
# Ottoman Empire
# Ottoman Empire
# Portugal
# Portugal
# Portugal
# Rome
# Rome
# Rome
# Rome
# Scotland
# Spain
# Spain
# Swiss Cantons
# Swiss Cantons
# Swiss Cantons
# Swiss Cantons
# Swiss Cantons
# Swiss Cantons
# Swiss Cantons
# Venice
# Venice
# Venice
# Venice
# Venice
# Denmark
# Denmark
# Denmark
# Denmark
# England
# Grisons
# Grisons
# Grisons
# Grisons
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Netherlands
# Netherlands
# Netherlands
# Netherlands
# Ottoman Empire
# Ottoman Empire
# ...

# %%
# itertuples
for item in df.itertuples():
    print(item)
# Out:
# Pandas(Index=0, id=0, name='Richer, Christophe', place='Denmark', year=1543, lat=55.68, long=12.57, lat_long='55.68, 12.57')
# Pandas(Index=1, id=1, name='Richer, Christophe', place='Denmark', year=1541, lat=55.68, long=12.57, lat_long='55.68, 12.57')
# Pandas(Index=2, id=2, name='Danzay, Charles de', place='Denmark', year=1561, lat=55.68, long=12.57, lat_long='55.68, 12.57')
# Pandas(Index=3, id=3, name='Danzay, Charles de', place='Denmark', year=1563, lat=55.68, long=12.57, lat_long='55.68, 12.57')
# Pandas(Index=4, id=4, name='Danzay, Charles de', place='Denmark', year=1582, lat=55.68, long=12.57, lat_long='55.68, 12.57')
# Pandas(Index=5, id=5, name='Bapaume, Robert de', place='England', year=1516, lat=51.51, long=-0.12, lat_long='51.51, -0.12')
# Pandas(Index=6, id=6, name='Passano, Jean-Joachim de', place='England', year=1527, lat=51.51, long=-0.12, lat_long='51.51, -0.12')
# ...

# %%
for idx, id, n, p, y, lt, lg, _ in df.itertuples():
    print(p)
# Out:
# Denmark
# Denmark
# Denmark
# Denmark
# Denmark
# England
# England
# England
# England
# England
# England
# England
# England
# England
# England
# Geneva
# Grisons
# Grisons
# Grisons
# Grisons
# Grisons
# Grisons
# Grisons
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Netherlands
# Ottoman Empire
# Ottoman Empire
# Ottoman Empire
# Ottoman Empire
# Ottoman Empire
# Portugal
# Portugal
# Portugal
# Rome
# Rome
# Rome
# Rome
# Scotland
# Spain
# Spain
# Swiss Cantons
# Swiss Cantons
# Swiss Cantons
# Swiss Cantons
# Swiss Cantons
# Swiss Cantons
# Swiss Cantons
# Venice
# Venice
# Venice
# Venice
# Venice
# Denmark
# Denmark
# Denmark
# Denmark
# England
# Grisons
# Grisons
# Grisons
# Grisons
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Holy Roman Empire
# Netherlands
# Netherlands
# Netherlands
# Netherlands
# Ottoman Empire
# Ottoman Empire
# ...

# %%
# rename Denmark with itertuples:
for item in df.itertuples():
    if item.place == "Denmark":
        df.at[item.Index, "place"] = "Den."
        
df["place"].unique()
# Out:
# <StringArray>
# [             'Den.',           'England',            'Geneva',
#            'Grisons', 'Holy Roman Empire',       'Netherlands',
#     'Ottoman Empire',          'Portugal',              'Rome',
#           'Scotland',             'Spain',     'Swiss Cantons',
#             'Venice',            'Poland',             'Savoy',
#            'Ferrara',            'Saxony',           'Tuscany']
# Length: 18, dtype: str

# %%
# df.loc[] to rename only one variable name
df.loc[df["place"] == "England", "place"] = "Eng."
df["place"].unique()
# Out:
# <StringArray>
# [             'Den.',              'Eng.',            'Geneva',
#            'Grisons', 'Holy Roman Empire',       'Netherlands',
#     'Ottoman Empire',          'Portugal',              'Rome',
#           'Scotland',             'Spain',     'Swiss Cantons',
#             'Venice',            'Poland',             'Savoy',
#            'Ferrara',            'Saxony',           'Tuscany']
# Length: 18, dtype: str

# %%
# how a hashmap works
l1 = ["a", "b", "c", "d"]

h1 = {"a" : "Alpha", "b": "Beta"}

l1 = [h1.get(l, l) for l in l1]
l1
# Out:
# ['Alpha', 'Beta', 'c', 'd']

# %%
# hash = {
#     "Geneva": "Gen.",
#     "Grisons": "Gri.",
# }

hash = {
    place:f"{place[:3]}." for place in df["place"].unique() 
    }

df['place'] = df["place"].replace(hash)
df["place"].unique()
# Out:
# <StringArray>
# ['Den.', 'Eng.', 'Gen.', 'Gri.', 'Hol.', 'Net.', 'Ott.', 'Por.', 'Rom.',
#  'Sco.', 'Spa.', 'Swi.', 'Ven.', 'Pol.', 'Sav.', 'Fer.', 'Sax.', 'Tus.']
# Length: 18, dtype: str

# %%
df.head()
# Out:
#    id                name place  year    lat   long      lat_long
# 0   0  Richer, Christophe  Den.  1543  55.68  12.57  55.68, 12.57
# 1   1  Richer, Christophe  Den.  1541  55.68  12.57  55.68, 12.57
# 2   2  Danzay, Charles de  Den.  1561  55.68  12.57  55.68, 12.57
# 3   3  Danzay, Charles de  Den.  1563  55.68  12.57  55.68, 12.57
# 4   4  Danzay, Charles de  Den.  1582  55.68  12.57  55.68, 12.57

# %%
df.loc[(df["place"] == "Eng.") & (df["year"] >= 1550) & (df["year"] <= 1555)].count()
# Out:
# id          8
# name        8
# place       8
# year        8
# lat         8
# long        8
# lat_long    8
# dtype: int64

# %%
df.loc[~(df["place"] == "Eng.") & (df["year"] >= 1550) & (df["year"] <= 1555)].count()
# Out:
# id          61
# name        61
# place       61
# year        61
# lat         61
# long        61
# lat_long    61
# dtype: int64

# %%
imp_emb = ["Ven.", "Eng.", "Ott."]

imp_num = df.loc[(df["place"].isin(imp_emb)) & (df["year"] >= 1550) & (df["year"] <= 1555)].count()
non_imp_num = df.loc[~(df["place"].isin(imp_emb)) & (df["year"] >= 1550) & (df["year"] <= 1555)].count()
all_num = df.loc[(df["year"] >= 1550) & (df["year"] <= 1555)].count()

print(f"all ambs: {all_num}")
print(f"% to imp: {imp_num / all_num}")
print(f"% to non_imp: {non_imp_num / all_num}")
# Out:
# all ambs: id          69
# name        69
# place       69
# year        69
# lat         69
# long        69
# lat_long    69
# dtype: int64
# % to imp: id          0.376812
# name        0.376812
# place       0.376812
# year        0.376812
# lat         0.376812
# long        0.376812
# lat_long    0.376812
# dtype: float64
# % to non_imp: id          0.623188
# name        0.623188
# place       0.623188
# year        0.623188
# lat         0.623188
# long        0.623188
# lat_long    0.623188
# dtype: float64
