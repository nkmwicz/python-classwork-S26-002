# %% [markdown]
# # Collections
#
# - set
# - tuple
# - list
# - dict (dictionary)

# %%
# Set
# mutable, unorderd (no index), no duplicates, iterable

set_inferred = {1,2,3,2} # almost never do this
set_explicit = set([2,3,4,4])

print(f"set inferred = {set_inferred}")
print(f"set explicit = {set_explicit}")
# Out:
# set inferred = {1, 2, 3}
# set explicit = {2, 3, 4}

# %%
set_inferred.add(7) # add
print(f"add = {set_inferred}")
# remove
set_inferred.remove(3)
print(f"remove set inferred = {set_inferred}")
# get the difference between sets
diff = set_inferred.difference(set_explicit)
print(f"diff = {diff}")
# get Overlaps between sets
overlap = set_inferred.intersection(set_explicit)
print(f"overlap = {overlap}")
# Out:
# add = {1, 2, 3, 7}
# remove set inferred = {1, 2, 7}
# diff = {1, 7}
# overlap = {2}

# %%
# tuple
# immutable, ordered (index), duplicates, iterable
tuple_inferred = (1,2,3,3,5,6)
tuple_explicit = tuple([4,5,6,7,2])

print(f"tuple inferred = {tuple_inferred}")
print(f"tuple explicit = {tuple_explicit}")
# Out:
# tuple inferred = (1, 2, 3, 3, 5, 6)
# tuple explicit = (4, 5, 6, 7, 2)

# %%
# index notation
# [start:stop:step]
print(f"index 0 = {tuple_inferred[0]}")
print(f"last item = {tuple_inferred[-1]}")
print(f"get 2nd and 3rd items = {tuple_inferred[1:3]}")
print(f"all but the last three = {tuple_inferred[:-3]}")
print(f"We only want the last three = {tuple_inferred[-3:]}")
print(f"tuple inferred  has {len(tuple_inferred)} elements")
# Out:
# index 0 = 1
# last item = 6
# get 2nd and 3rd items = (2, 3)
# all but the last three = (1, 2, 3)
# We only want the last three = (3, 5, 6)
# tuple inferred  has 6 elements

# %%
# tuple methods
count = tuple_inferred.count(3) # get number of value
idx = tuple_inferred.index(3) # get index of value
print(count)
print(idx)
# Out:
# 2
# 2

# %%
# list
# mutable, ordered (index), duplicates, iterable
list_inferred = [1,2,3,4,5,5,6,3]
list_explicit = list((4,5,6,1,1,3,2))

print(f"list inferred = {list_inferred}")
print(f"list_explicit = {list_explicit}")
# Out:
# list inferred = [1, 2, 3, 4, 5, 5, 6, 3]
# list_explicit = [4, 5, 6, 1, 1, 3, 2]

# %%
# list methods

newlist = list_inferred.append(7)# add
print(f"append = {list_inferred}")
print(f"new list = {newlist}")

list_inferred.remove(5) # remove
print(f"remove = {list_inferred}")

# pop
removed = list_inferred.pop() # removes las item or at index
print(f"removed = {removed}")
print(f"after pop = {list_inferred}")
# Out:
# append = [1, 2, 3, 4, 5, 6, 3, 7, 7]
# new list = None
# remove = [1, 2, 3, 4, 6, 3, 7, 7]
# removed = 7
# after pop = [1, 2, 3, 4, 6, 3, 7]

# %%
# changing
list_inferred[0] = "Awesome Index"
list_inferred
# Out:
# ['Awesome Index', 2, 3, 4, 6, 3, 7]

# %%
# dict (dictionary)
# mutable, {key:value}, unordered (index by key), 
# no duplicate keys, but duplicate values, iterable
dict_inferred = {
    "name": "John",
    "age": 30,
}
dict_explicit = dict(city="new york", country="usa")

print(f"dict inferred = {dict_inferred}")
print(f"dict explicit = {dict_explicit}")
# Out:
# dict inferred = {'name': 'John', 'age': 30}
# dict explicit = {'city': 'new york', 'country': 'usa'}

# %%
dict_inferred["age"]
# Out:
# 30

# %%
dict_inferred["gender"] = "m"
dict_inferred
# Out:
# {'name': 'John', 'age': 30, 'gender': 'm'}

# %%
dict_inferred["age"] = 72
dict_inferred
# Out:
# {'name': 'John', 'age': 72, 'gender': 'm'}

# %%
person1 = {
    "name": "Alice",
    "home": "NC",
}
person2 = {
    "name": "Nathan",
    "home": "GA",
}
people = [person1, person2]
people
# Out:
# [{'name': 'Alice', 'home': 'NC'}, {'name': 'Nathan', 'home': 'GA'}]

# %%
people[0]["name"] = "Rebecca"
people
# Out:
# [{'name': 'Rebecca', 'home': 'NC'}, {'name': 'Nathan', 'home': 'GA'}]

# %%
people.append({"name": "Jay", "home": "NY"})
people[-1]
# Out:
# {'name': 'Jay', 'home': 'NY'}

# %%
cool = ["r", "k", "b", "k", "q", "b", "k", "r"]
pawns = ["p"] * 8
empties = [""] * 8
board = [
    cool.copy(),
    pawns.copy(),
    empties.copy(),
    empties.copy(),
    empties.copy(),
    empties.copy(),
    pawns.copy(),
    cool.copy(),
]
board
# Out:
# [['r', 'k', 'b', 'k', 'q', 'b', 'k', 'r'],
#  ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p'],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p'],
#  ['r', 'k', 'b', 'k', 'q', 'b', 'k', 'r']]

# %%
board[0][1] = ""
board[2][0] = "k"
board
# Out:
# [['r', '', 'b', 'k', 'q', 'b', 'k', 'r'],
#  ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p'],
#  ['k', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '', ''],
#  ['p', 'p', 'p', 'p', 'p', 'p', 'p', 'p'],
#  ['r', 'k', 'b', 'k', 'q', 'b', 'k', 'r']]
