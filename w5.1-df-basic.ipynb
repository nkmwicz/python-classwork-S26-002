# %% [markdown]
# - Pandas?
# - Series?
# - DataFrame?
# - create df
# - create/update columns
# - vectorized operations
# - change values
# - .loc => filtering

# %%
# %conda install pandas # if you do not already have pandas
import pandas as pd
